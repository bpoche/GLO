# %% [markdown]
# ## IMU ISM Test 2/15/18
# ## PTU D-48E with ISM mounted on top of PTU D300 ebay
# ## Note: Axes need to be recalibrated after change of step mode
#
# 4.6 - Output Filter (values 0.0 to 1.0)
# This filter can reduce jittery movements and make controls smoother. Increasing filter strength (lower
# values) lengthens the life of the PTU but can negative
# ly impact system performance at high disturbance
# frequency
#
# set pan axis filter to 0.5
# SCPKS.5*
#
# The following example sets the stabilization pan axis proportional gain and then verifies the setting:
# SCPKP16.00000 *
# SCPKP * 16.00000
#
# 4.7 - Adjust Controller Acceleration
# Feed-Forward
# Query or set the pan and tilt acceleration feed-for
# ward. This determines how far ahead in samples the
# PTU attempts to estimate. If the PTU undergoes reason
# ably smooth motion (such as a boat or a vehicle
# with good suspension), leave this value at defa
# ult. Decrease this value for rougher movements

# %%
#Test 1: 20180215 9:45am
#PTUD47-ISM mounted on top of PTUD300_ebay. 
#ISM NOT engaged
#base unit - sweeping at different speeds to see how stable laser is by just moving base
#0:06 po50
# ~1min


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0100.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=1.0
output_filter_tilt=1.0
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 2: 20180215 9:47am
#PTUD47-ISM mounted on top of PTUD300_ebay. 
#ISM NOT engaged
#base unit - sweeping at different speeds to see how stable laser is by just moving base
#0:03 po-50
# video length ~32seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0101.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=1.0
output_filter_tilt=1.0
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 3: 20180215 9:47am
#PTUD47-ISM mounted on top of PTUD300_ebay. 
#ISM NOT engaged
#base unit - sweeping at ps4
#~0:03 po100
# video length ~29seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0102.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=1.0
output_filter_tilt=1.0
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 4: 20180215 9:47am
#PTUD47-ISM mounted on top of PTUD300_ebay. 
#ISM NOT engaged
#base unit - sweeping at ps8
#~0:03 po-100
# video length ~29seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0103.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=1.0
output_filter_tilt=1.0
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 5: 20180215 9:47am
#PTUD47-ISM mounted on top of PTUD300_ebay. 
#ISM NOT engaged
#base unit - sweeping at ps16
#~0:03 po100
# video length ~10seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0104.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=1.0
output_filter_tilt=1.0
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 6: 20180215 9:49am
#PTUD47-ISM mounted on top of PTUD300_ebay. 
#ISM NOT engaged
#base unit - sweeping at ps30
#~0:01 po-100
# video length ~7 seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0105.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=1.0
output_filter_tilt=1.0
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 7: 20180215 9:50am
#PTUD47-ISM mounted on top of PTUD300_ebay. 
#ISM NOT engaged
#base unit - sweeping at ps60
#~0:01 po100
# video length ~4 seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0106.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=1.0
output_filter_tilt=1.0
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 8: 20180215 9:51am
#PTUD47-ISM mounted on top of PTUD300_ebay. 
#ISM NOT engaged
#base unit - sweeping at ps100
#~0:01 po-100
# video length ~5 seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0107.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=1.0
output_filter_tilt=1.0
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 9: 20180215 9:51am
#PTUD47-ISM mounted on top of PTUD300_ebay. 
#ISM NOT engaged
#base unit - sweeping at ps200
#~0:01 po200
# video length ~5 seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0108.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=1.0
output_filter_tilt=1.0
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 10: 20180215 9:52am
#PTUD47-ISM mounted on top of PTUD300_ebay. 
#ISM NOT engaged
#base unit - sweeping at ps300
#~0:01 po-200
# video length ~4 seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0109.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=1.0
output_filter_tilt=1.0
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 10: 20180215 9:53am
#PTUD47-ISM mounted on top of PTUD300_ebay. 
#ISM NOT engaged
#base unit - sweeping at ps400
#~0:01 po200
# video length ~5 seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0110.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=1.0
output_filter_tilt=1.0
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 11: 20180215 9:53am
#PTUD47-ISM mounted on top of PTUD300_ebay. 
#ISM NOT engaged
#base unit - sweeping at ps400
#~0:01 po200
# video length ~5 seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0110.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=1.0
output_filter_tilt=1.0
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 12: 20180215 2:41pm
#PTUD47-ISM mounted on top of PTUD300_ebay. 
#ISM NOT engaged at 10 seconds
#base unit - sweeping with a sine wave
#~0:10 ISM enabled
#~0:45 sine wave started
#~1:10 manually recentered
# video length ~3 minutes??

#Sine wave sweep parameters
period=120 #seconds
duration=60 #seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0112.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=1.0
output_filter_tilt=1.0
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 13: 20180215 2:47pm
#PTUD47-ISM mounted on top of PTUD300_ebay. 
#ISM engaged before startup
#base unit - sweeping with a sine wave
#~0:00 ISM enabled before startup
#~0:25 sine wave started
# video length ~ 03:04

#Sine wave sweep parameters
period=30 #seconds
duration=120 #seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0113.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=1.0
output_filter_tilt=1.0
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 14: 20180215 2:53pm
#PTUD47-ISM mounted on top of PTUD300_ebay. 
#ISM engaged before startup
#base unit - sweeping with a sine wave (longer period 120s)
#~0:00 ISM still enabled 
#~0:15 sine wave started
#01:06 manual recenter
#02:07 manual recenter
# video length ~ 02:55

#Sine wave sweep parameters
period=120 #seconds
duration=120 #seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0114.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=1.0
output_filter_tilt=1.0
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 15: 20180215 2:57pm
#PTUD47-ISM mounted on top of PTUD300_ebay. 
#ISM engaged before startup (change filters to 0.5)
#base unit - sweeping with a sine wave 
#~0:10 ISM enabled 
#~0:25 sine sweep started (5 second delay)
#~00:40-00:50 manual recenter (took a while)
#01:15 - manual recenter
#02:16 - manual recenter
#03:01 - manual recenter
#video length ~ 03:07

#Sine wave sweep parameters
period=30 #seconds
duration=120 #seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0115.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=0.1
output_filter_tilt=0.1
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 15: 20180215 2:57pm
#PTUD47-ISM mounted on top of PTUD300_ebay. 
#ISM engaged before startup 
#base unit - sweeping with a sine wave (longer period 120s)
#~0:10 ISM still running from last test
#~0:10 sine sweep started (5 second delay)
#~01:39 - manual recenter

#video length ~02:48

#Sine wave sweep parameters
period=120 #seconds
duration=120 #seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0116.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=0.1
output_filter_tilt=0.1
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 16: 20180215 3:04pm
#IGNORE
#PTUD47-ISM mounted on top of PTUD300_ebay. 
#ISM not engaged (mistake)
#base unit - sweeping with a sine wave 
#~0:10 ISM still running from last test
#~0:10 sine sweep started (5 second delay)


#video length ~??

#Sine wave sweep parameters
period=30 #seconds
duration=120 #seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0117.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=0.5
output_filter_tilt=0.5
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 16: 20180215 3:07pm
#IGNORE
#PTUD47-ISM mounted on top of PTUD300_ebay. 
#ISM engaged
#base unit - sweeping with a sine wave 
#~0:10 ISM engaged 
#~0:14 sine sweep started (5 second delay)


#video length ~ended early

#Sine wave sweep parameters
period=30 #seconds
duration=120 #seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0118.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=0.5
output_filter_tilt=0.5
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 17: 20180215 3:17pm??
#PTUD47-ISM mounted on top of PTUD300_ebay. 
#ISM engaged
#base unit - sweeping with a sine wave 
#~0:10 ISM engaged 
#~0:40 sine sweep started (5 second delay)
#01:22 manual recenter
#02:04 manual recenter
#02:35 manual recenter
#02:45 manual recenter
#video length ~03:29

#Sine wave sweep parameters
period=30 #seconds
duration=120 #seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0119.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=0.5
output_filter_tilt=0.5
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 18: 20180215 3:33pm
#PTUD47-ISM mounted on top of PTUD300_ebay.
#ISM RECALIBRATED before start of video
#ISM engaged at 3 seconds
#base unit - sweeping with a sine wave 

#00:03 ISM engaged
#00:40 sine wave started
#02:20 manual recenter

#video length ~03:17

#Sine wave sweep parameters
period=120 #seconds
duration=120 #seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0120.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=0.5
output_filter_tilt=0.5
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 19: 20180215 3:41pm
#PTUD47-ISM mounted on top of PTUD300_ebay.
#No ISM
#top unit - linear motion across at 1 pos/sec
#base unit - stable

#video length ~??

#Sine wave sweep parameters
period=120 #seconds
duration=120 #seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0120.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=0.5
output_filter_tilt=0.5
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 19: 20180215 3:42pm
#PTUD47-ISM mounted on top of PTUD300_ebay.
#No ISM
#top unit - linear motion across at 2 pos/sec
#base unit - stable 
#00:00 
#video length ~0:32

#Sine wave sweep parameters
period=120 #seconds
duration=120 #seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0120.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=0.5
output_filter_tilt=0.5
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 19: 20180215 3:43pm
#PTUD47-ISM mounted on top of PTUD300_ebay.
#No ISM
#top unit - linear motion across at 4 pos/sec
#base unit - stable 
#00:00 
#video length ~0:18

#Sine wave sweep parameters
period=120 #seconds
duration=120 #seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0120.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=0.5
output_filter_tilt=0.5
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 19: 20180215 3:43pm
#PTUD47-ISM mounted on top of PTUD300_ebay.
#No ISM
#top unit - linear motion across at 8 pos/sec
#base unit - stable 
#00:00 
#video length ~0:14?

#Sine wave sweep parameters
period=120 #seconds
duration=120 #seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0120.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=0.5
output_filter_tilt=0.5
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 20: 20180215 3:44pm
#IGNORE VIDEO
#PTUD47-ISM mounted on top of PTUD300_ebay.
#No ISM
#top unit - linear motion across at 8 pos/sec
#base unit - stable 
#00:00 
#video length ~0:04

#Sine wave sweep parameters
period=120 #seconds
duration=120 #seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0120.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=0.5
output_filter_tilt=0.5
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 21: 20180215 3:44pm
#PTUD47-ISM mounted on top of PTUD300_ebay.
#No ISM
#top unit - linear motion across at 16 pos/sec
#base unit - stable 
#00:00 
#video length ~0:09

#Sine wave sweep parameters
period=120 #seconds
duration=120 #seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0120.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=0.5
output_filter_tilt=0.5
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 20: 20180215 3:45pm
#PTUD47-ISM mounted on top of PTUD300_ebay.
#No ISM
#top unit - linear motion across at 30 pos/sec
#base unit - stable 
#00:00 
#video length ~0:06

#Sine wave sweep parameters
period=120 #seconds
duration=120 #seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0120.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=0.5
output_filter_tilt=0.5
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 20: 20180215 3:45pm
#PTUD47-ISM mounted on top of PTUD300_ebay.
#No ISM
#top unit - linear motion across at 60 pos/sec
#base unit - stable 
#00:00 
#video length ~0:06

#Sine wave sweep parameters
period=120 #seconds
duration=120 #seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0120.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=0.5
output_filter_tilt=0.5
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 20: 20180215 3:46pm
#PTUD47-ISM mounted on top of PTUD300_ebay.
#No ISM
#top unit - linear motion across at 100 pos/sec
#base unit - stable 
#00:00 
#video length ~0:05

#Sine wave sweep parameters
period=120 #seconds
duration=120 #seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0120.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=0.5
output_filter_tilt=0.5
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 20: 20180215 3:46pm
#PTUD47-ISM mounted on top of PTUD300_ebay.
#No ISM
#top unit - linear motion across at 200 pos/sec
#base unit - stable 
#00:00 
#video length ~0:04

#Sine wave sweep parameters
period=120 #seconds
duration=120 #seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0120.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=0.5
output_filter_tilt=0.5
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387

# %%
#Test 20: 20180215 3:46pm
#PTUD47-ISM mounted on top of PTUD300_ebay.
#No ISM
#top unit - linear motion across at 300 pos/sec
#base unit - stable 
#00:00 
#video length ~0:05

#Sine wave sweep parameters
period=120 #seconds
duration=120 #seconds


distance=71.0  #feet
file = "D:\DCIM\100GOPRO\GOPR0120.MP4"
kp_pan=12.0
kp_tilt=12.0
ka_pan=6.0
ka_tilt=6.0
vel_dband_pan=0.0
vel_dband_tilt=0.0
pos_dband_pan=0.0
pos_dband_tilt=0.0
output_filter_pan=0.5
output_filter_tilt=0.5
bias_x=0.000279
bias_y=-0.000755
bias_z=-0.000387
